# %% [markdown]
# Welcome to PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv("Desktop/Pandas/ex_1/survey_results_public.csv")

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
df.head(20)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                     I am a developer by profession
# 1            2                     I am a developer by profession
# 2            3                     I am a developer by profession
# 3            4                              I am learning to code
# 4            5                     I am a developer by profession
# 5            6                        I code primarily as a hobby
# 6            7  I am not primarily a developer, but I write co...
# 7            8                              I am learning to code
# 8            9                        I code primarily as a hobby
# 9           10                     I am a developer by profession
# 10          11  I used to be a developer by profession, but no...
# 11          12                     I am a developer by profession
# 12          13                     I am a developer by profession
# ...

# %%
df.shape
# Out:
# (65437, 114)

# %%
pd.set_option("display.max_rows",114)

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.tail()
# Out:
#        ResponseId                      MainBranch              Age  \
# 65432       65433  I am a developer by profession  18-24 years old
# 65433       65434  I am a developer by profession  25-34 years old
# 65434       65435  I am a developer by profession  25-34 years old
# 65435       65436  I am a developer by profession  18-24 years old
# 65436       65437     I code primarily as a hobby  18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# 65432  Employed, full-time                                Remote  Apples
# 65433  Employed, full-time                                Remote  Apples
# 65434  Employed, full-time                             In-person  Apples
# 65435  Employed, full-time  Hybrid (some remote, some in-person)  Apples
# 65436   Student, full-time                                   NaN  Apples
#
#                                         CodingActivities  \
# 65432                      Hobby;School or academic work
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 65427       65428  I am not primarily a developer, but I write co...
# 65428       65429                     I am a developer by profession
# 65429       65430                              I am learning to code
# 65430       65431                              I am learning to code
# 65431       65432                     I am a developer by profession
# 65432       65433                     I am a developer by profession
# 65433       65434                     I am a developer by profession
# 65434       65435                     I am a developer by profession
# 65435       65436                     I am a developer by profession
# 65436       65437                        I code primarily as a hobby
#
#                    Age                                         Employment  \
# 65427  25-34 years old  Not employed, but looking for work;Employed, p...
# ...

# %%
schema_df=pd.read_csv("desktop/Pandas/ex_1/survey_results_schema.csv")

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         87 non-null     object
#  1   qname       87 non-null     object
#  2   question    87 non-null     object
#  3   force_resp  66 non-null     object
#  4   type        87 non-null     object
#  5   selector    87 non-null     object
# dtypes: object(6)
# memory usage: 4.2+ KB

# %%
schema_df.head(15)
# Out:
#        qid              qname  \
# 0     QID2         MainBranch
# 1   QID127                Age
# 2   QID296         Employment
# 3   QID308         RemoteWork
# 4   QID341              Check
# 5   QID297   CodingActivities
# 6    QID25            EdLevel
# 7   QID276          LearnCode
# 8   QID281    LearnCodeOnline
# 9   QID331            TechDoc
# 10   QID32          YearsCode
# 11   QID34       YearsCodePro
# 12   QID31            DevType
# 13   QID29            OrgSize
# 14  QID278  PurchaseInfluence
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# ...

# %%
schema_df.tail(15)
# Out:
#        qid            qname  \
# 72  QID289      Knowledge_7
# 73  QID289      Knowledge_8
# 74  QID289      Knowledge_9
# 75  QID290      Frequency_1
# 76  QID290      Frequency_2
# 77  QID290      Frequency_3
# 78  QID337   JobSatPoints_1
# 79  QID337   JobSatPoints_4
# 80  QID337   JobSatPoints_5
# 81  QID337   JobSatPoints_6
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 72  Waiting on answers to questions often causes i...        NaN   MC     MAVR
# 73  I feel like I have the tools and/or resources ...        NaN   MC     MAVR
# 74  I have asked my employer to reimburse me for t...        NaN   MC     MAVR
# 75  Needing help from people outside of your immed...        NaN   MC     MAVR
# 76  Interacting with people outside of your immedi...        NaN   MC     MAVR
# ...

# %%
pd.set_option("display.max_rows",86)

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...
