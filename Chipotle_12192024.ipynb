# %% [markdown]
# Github-1,2..

# %%
import pandas as pd
import numpy as np

# %%
url ='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo=pd.read_csv(url,sep='\t')#delimiter='\t'

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
a = chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False)

# %%
a.head(1)
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
chipo.head(3)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
# 2         1         1              Nantucket Nectar            [Apple]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39

# %%
a=chipo.groupby('choice_description')['quantity'].sum().sort_values(ascending=False)

# %%
a.head(5)
# Out:
# choice_description
# [Diet Coke]                                                               159
# [Coke]                                                                    143
# [Sprite]                                                                   89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]     49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]              42
# Name: quantity, dtype: int64

# %%
b=chipo['quantity'].sum()
b
# Out:
# 4972

# %%
chipo['item_price']=chipo['item_price'].apply(lambda x:float(x[1:-1]))

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
revenue= (chipo['quantity'] * chipo['item_price']).sum()
print("revenue is $:",str(np.round(revenue,2)))
# Out:
# revenue is $: 39237.02

# %%
count=chipo['order_id'].value_counts().count()
count
# Out:
# 1834

# %%
chipo['revenue']=chipo['quantity']*chipo['item_price']
average_revenue=chipo.groupby('order_id')['revenue'].sum().mean()
print((np.round(average_revenue,3)))
# Out:
# 21.394

# %%
b=chipo['item_name'].value_counts().count()
b
# Out:
# 50

# %%
chipo.head(4)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price  revenue
# 0                NaN        2.39     2.39
# 1       [Clementine]        3.39     3.39
# 2            [Apple]        3.39     3.39
# 3                NaN        2.39     2.39

# %%
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# revenue               float64
# dtype: object

# %%
a=chipo.drop_duplicates(['quantity','item_name','choice_description'])
b=a[a['quantity']==1]
#a['price_per_item']=a['item_price']/a['quantity']
b
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4602      1827         1                       Barbacoa Burrito
# 4607      1829         1                          Steak Burrito
# 4610      1830         1                          Steak Burrito
# 4611      1830         1                         Veggie Burrito
# 4612      1831         1                          Carnitas Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...

# %%
high_price =b[b['item_price']>10.00]
high_price.head(50)
# Out:
#      order_id  quantity              item_name  \
# 5           3         1           Chicken Bowl
# 7           4         1          Steak Burrito
# 13          7         1           Chicken Bowl
# 23         12         1        Chicken Burrito
# 39         19         1          Barbacoa Bowl
# 42         20         1           Chicken Bowl
# 43         20         1          Steak Burrito
# 45         21         1        Chicken Burrito
# 52         24         1        Chicken Burrito
# 57         26         1         Veggie Burrito
# 62         28         1            Veggie Bowl
# 79         35         1     Chicken Soft Tacos
# 90         40         1             Steak Bowl
# 91         40         1             Steak Bowl
# 93         41         1       Carnitas Burrito
# 97         43         1          Carnitas Bowl
# 123        54         1           Chicken Bowl
# 130        57         1       Barbacoa Burrito
# 134        59         1        Chicken Burrito
# ...

# %%
chipo['price_item']=chipo['item_price'] / chipo['quantity']
chipo[['item_name','price_item']].reset_index(drop=True) #to_numpy()
# Out:
#                                   item_name  price_item
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl        8.49
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
chipo.sort_values(by='item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  revenue  \
# 3389                                        [Diet Coke]       12.98    25.96
# 341                                         [Diet Coke]        6.49     6.49
# 1849                                             [Coke]        6.49     6.49
# 1860                                        [Diet Coke]        6.49     6.49
# ...

# %%
chipo.sort_values(by='item_price',ascending=False).head(1)#[['quantity','item_name']]
# Out:
#       quantity                     item_name
# 3598        15  Chips and Fresh Tomato Salsa

# %%
a=chipo[chipo['item_name']=='Veggie Salad Bowl']
a
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price  revenue  \
# ...

# %%
a=chipo[chipo['item_name']=='Veggie Salad Bowl']
a[['order_id',	'quantity',	'item_name','choice_description']]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description
# 186   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# ...

# %%
chipo[(chipo['item_name']=='Canned Soda') & (chipo['quantity']>1)].shape[0]
#or
#len(chipo[(chipo['item_name']=='Canned Soda') & (chipo['quantity']>1)])
# Out:
# 20
